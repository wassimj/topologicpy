# %% [markdown]
# # End-to-end PyTorch Artificial Neural Network training, validation, and testing tutorial for a TopologicPy Dataset

# %% [markdown]
# ## This Script
#
# 1. Loads the dataset with the ANN helper class
# 2. Builds a PyTorch ANN model (classification by default)
# 3. Trains with a train/val split
# 4. Evaluates on validation and test sets
# 5. Visualizes learning curves, confusion matrix, and prints evaluation metrics
#
# ---
#
# ## Notes
#
# - **Requires:** `topologicpy > 0.9.6`, `torch`, `pandas`, `pyyaml`, `numpy`, `plotly`, `scikit-learn`
# - **Example Datasets can found at** `https://github.com/wassimj/topologicpy/tree/main/assets/MachineLearning`
#
# ### Installation Example
#
# ```bash
# pip install torch pandas pyyaml numpy plotly scikit-learn
# # then install torch-geometric following their official instructions for your OS/CUDA

# %%
# This cell is not needed if you have pip installed topologicpy
import sys
sys.path.append("C:/Users/sarwj/OneDrive - Cardiff University/Documents/GitHub/topologicpy/src")

# %% [markdown]
# ### Import the needed libraries and add a utility function

# %%
from __future__ import annotations
import pandas as pd
from topologicpy.ANN import ANN
from topologicpy.Helper import Helper

# %% [markdown]
# ### Check TopologicPy Version

# %%
print("The script is compatible with TopologicPy v0.9.6 or newer.")
print(Helper.Version())
# Out:
# The script is compatible with TopologicPy v0.9.6 or newer.
# The version that you are using (0.9.6) is EQUAL TO the latest version available on PyPI.

# %% [markdown]
# ### Specify the Location of the Training Dataset

# %%
path=r"C:\Users\sarwj\OneDrive - Cardiff University\Documents\GitHub\topologicpy\assets\MachineLearning\synthetic_small.csv"

# %% [markdown]
# ### Load the CSV Dataset (The Example Has Categorical Labels, Task is Graph-level Classification)

# %%
# IMPORTANT: ANN.ByCSVPath expects a FILE path (not a folder)
ann = ANN.ByCSVPath(
path=path,
task="classification",
featuresKeys=[f"x{i}" for i in range(50)],
labelHeader="label"
)

# %% [markdown]
# ### Set Hyperparameters

# %%
# IMPORTANT: epochs/batch_size are set via SetHyperparameters (Train() takes no args)
ann.SetHyperparameters(
epochs=125,
batch_size=3,          # <-- FIX (avoids batch size 1 with 5 training samples)
lr=1e-4,
weight_decay=1e-4,
hidden_dims=(64, 64),
dropout=0.1,
batch_norm=True,
early_stopping=True,
early_stopping_patience=20,
verbose=True
)

# %% [markdown]
# ### Train the Model

# %%
history = ann.Train()
# Out:
# Epoch 001/125: train_loss=1.576394, val_loss=1.406928
# Epoch 002/125: train_loss=1.451666, val_loss=1.268080
# Epoch 003/125: train_loss=1.387208, val_loss=1.186334
# Epoch 004/125: train_loss=1.355674, val_loss=1.164682
# Epoch 005/125: train_loss=1.330808, val_loss=1.118697
# Epoch 006/125: train_loss=1.316929, val_loss=1.090494
# Epoch 007/125: train_loss=1.317085, val_loss=1.067774
# Epoch 008/125: train_loss=1.298381, val_loss=1.021253
# Epoch 009/125: train_loss=1.297166, val_loss=1.033188
# Epoch 010/125: train_loss=1.295044, val_loss=1.034929
# Epoch 011/125: train_loss=1.280333, val_loss=0.964638
# Epoch 012/125: train_loss=1.277552, val_loss=0.987840
# Epoch 013/125: train_loss=1.268345, val_loss=0.974182
# Epoch 014/125: train_loss=1.267703, val_loss=0.954397
# Epoch 015/125: train_loss=1.268512, val_loss=0.967355
# Epoch 016/125: train_loss=1.268156, val_loss=0.962473
# Epoch 017/125: train_loss=1.260289, val_loss=0.917163
# Epoch 018/125: train_loss=1.256380, val_loss=0.931854
# Epoch 019/125: train_loss=1.253357, val_loss=0.896613
# Epoch 020/125: train_loss=1.241367, val_loss=0.904600
# Epoch 021/125: train_loss=1.250848, val_loss=0.886243
# Epoch 022/125: train_loss=1.237802, val_loss=0.883391
# Epoch 023/125: train_loss=1.242605, val_loss=0.870049
# Epoch 024/125: train_loss=1.236743, val_loss=0.839390
# Epoch 025/125: train_loss=1.240602, val_loss=0.843566
# Epoch 026/125: train_loss=1.217168, val_loss=0.832734
# Epoch 027/125: train_loss=1.235772, val_loss=0.844463
# Epoch 028/125: train_loss=1.213918, val_loss=0.853850
# Epoch 029/125: train_loss=1.227120, val_loss=0.830852
# Epoch 030/125: train_loss=1.212069, val_loss=0.810938
# Epoch 031/125: train_loss=1.225117, val_loss=0.796396
# Epoch 032/125: train_loss=1.197644, val_loss=0.777878
# Epoch 033/125: train_loss=1.206352, val_loss=0.779002
# Epoch 034/125: train_loss=1.219696, val_loss=0.777681
# Epoch 035/125: train_loss=1.222884, val_loss=0.778281
# Epoch 036/125: train_loss=1.198829, val_loss=0.759513
# Epoch 037/125: train_loss=1.227490, val_loss=0.727002
# Epoch 038/125: train_loss=1.201375, val_loss=0.807218
# Epoch 039/125: train_loss=1.216255, val_loss=0.755834
# Epoch 040/125: train_loss=1.199690, val_loss=0.761032
# Epoch 041/125: train_loss=1.205201, val_loss=0.722667
# Epoch 042/125: train_loss=1.194420, val_loss=0.712483
# Epoch 043/125: train_loss=1.186244, val_loss=0.722777
# Epoch 044/125: train_loss=1.183611, val_loss=0.731571
# Epoch 045/125: train_loss=1.194067, val_loss=0.716536
# Epoch 046/125: train_loss=1.183018, val_loss=0.712952
# Epoch 047/125: train_loss=1.194926, val_loss=0.688548
# Epoch 048/125: train_loss=1.184424, val_loss=0.687224
# Epoch 049/125: train_loss=1.202549, val_loss=0.738486
# Epoch 050/125: train_loss=1.197302, val_loss=0.744683
# Epoch 051/125: train_loss=1.186965, val_loss=0.689441
# Epoch 052/125: train_loss=1.178667, val_loss=0.696192
# Epoch 053/125: train_loss=1.155978, val_loss=0.677762
# Epoch 054/125: train_loss=1.174577, val_loss=0.712056
# Epoch 055/125: train_loss=1.190025, val_loss=0.664973
# Epoch 056/125: train_loss=1.175980, val_loss=0.679085
# Epoch 057/125: train_loss=1.161081, val_loss=0.682146
# Epoch 058/125: train_loss=1.173030, val_loss=0.661310
# Epoch 059/125: train_loss=1.168112, val_loss=0.679228
# Epoch 060/125: train_loss=1.165073, val_loss=0.655314
# Epoch 061/125: train_loss=1.166285, val_loss=0.681252
# Epoch 062/125: train_loss=1.168938, val_loss=0.652704
# Epoch 063/125: train_loss=1.161399, val_loss=0.626311
# Epoch 064/125: train_loss=1.158307, val_loss=0.657774
# Epoch 065/125: train_loss=1.177090, val_loss=0.621856
# Epoch 066/125: train_loss=1.181247, val_loss=0.621931
# Epoch 067/125: train_loss=1.172093, val_loss=0.651157
# Epoch 068/125: train_loss=1.146678, val_loss=0.626494
# Epoch 069/125: train_loss=1.162155, val_loss=0.630461
# Epoch 070/125: train_loss=1.154272, val_loss=0.611005
# Epoch 071/125: train_loss=1.161469, val_loss=0.626183
# Epoch 072/125: train_loss=1.160171, val_loss=0.624477
# Epoch 073/125: train_loss=1.137525, val_loss=0.641907
# Epoch 074/125: train_loss=1.160583, val_loss=0.598503
# Epoch 075/125: train_loss=1.163508, val_loss=0.613931
# Epoch 076/125: train_loss=1.153645, val_loss=0.627519
# Epoch 077/125: train_loss=1.154623, val_loss=0.603285
# Epoch 078/125: train_loss=1.163681, val_loss=0.620026
# Epoch 079/125: train_loss=1.151808, val_loss=0.637130
# Epoch 080/125: train_loss=1.163609, val_loss=0.602241
# Epoch 081/125: train_loss=1.153163, val_loss=0.591187
# Epoch 082/125: train_loss=1.161266, val_loss=0.575150
# Epoch 083/125: train_loss=1.158904, val_loss=0.615632
# Epoch 084/125: train_loss=1.138590, val_loss=0.596403
# Epoch 085/125: train_loss=1.166720, val_loss=0.613975
# Epoch 086/125: train_loss=1.147599, val_loss=0.584787
# Epoch 087/125: train_loss=1.150588, val_loss=0.583140
# Epoch 088/125: train_loss=1.151420, val_loss=0.587765
# Epoch 089/125: train_loss=1.147926, val_loss=0.591811
# Epoch 090/125: train_loss=1.142372, val_loss=0.598517
# Epoch 091/125: train_loss=1.143496, val_loss=0.589133
# Epoch 092/125: train_loss=1.137031, val_loss=0.573895
# Epoch 093/125: train_loss=1.155079, val_loss=0.618936
# Epoch 094/125: train_loss=1.136479, val_loss=0.582069
# Epoch 095/125: train_loss=1.150241, val_loss=0.551754
# Epoch 096/125: train_loss=1.132529, val_loss=0.574618
# Epoch 097/125: train_loss=1.134118, val_loss=0.592652
# Epoch 098/125: train_loss=1.161031, val_loss=0.578073
# Epoch 099/125: train_loss=1.137240, val_loss=0.602806
# Epoch 100/125: train_loss=1.157239, val_loss=0.602427
# Epoch 101/125: train_loss=1.130800, val_loss=0.569095
# Epoch 102/125: train_loss=1.138872, val_loss=0.573657
# Epoch 103/125: train_loss=1.126277, val_loss=0.577068
# Epoch 104/125: train_loss=1.144264, val_loss=0.578175
# Epoch 105/125: train_loss=1.147232, val_loss=0.570791
# Epoch 106/125: train_loss=1.138585, val_loss=0.585367
# Epoch 107/125: train_loss=1.136507, val_loss=0.559670
# Epoch 108/125: train_loss=1.150755, val_loss=0.578705
# Epoch 109/125: train_loss=1.144572, val_loss=0.593535
# Epoch 110/125: train_loss=1.140844, val_loss=0.595311
# Epoch 111/125: train_loss=1.132101, val_loss=0.603981
# Epoch 112/125: train_loss=1.136657, val_loss=0.577204
# Epoch 113/125: train_loss=1.136404, val_loss=0.564303
# Epoch 114/125: train_loss=1.124164, val_loss=0.564221
# Epoch 115/125: train_loss=1.160920, val_loss=0.579020
# Early stopping triggered.

# %% [markdown]
# ### Validate the Model

# %%
val_metrics = ann.Validate()
print("\nValidation metrics:", {k: v for k, v in val_metrics.items() if k not in ("y_true", "y_pred", "y_prob")})
# Out:
# Validation metrics: {'accuracy': 0.8448, 'f1_macro': 0.8447565625373343, 'precision_macro': 0.8463216314544704, 'recall_macro': 0.8446003850262492}

# %% [markdown]
# ### Test the Model

# %%
test_metrics = ann.Test()
print("Test metrics:", {k: v for k, v in test_metrics.items() if k not in ("y_true", "y_pred", "y_prob")})
# Out:
# Test metrics: {'accuracy': 0.84, 'f1_macro': 0.8396405847770108, 'precision_macro': 0.8400993114534995, 'recall_macro': 0.8398854902371073}

# %% [markdown]
# ### Plot the Training and Validation Loss Curves

# %%
# Plot learning curves
fig_hist = ann.PlotHistory(title="ANN Learning Curves")
fig_hist.show()

# %% [markdown]
# ### Plot the Confusion Matrix (For Categorical Labels)

# %%
# Plot confusion matrix
fig_cm = ann.PlotConfusionMatrix(split="test", normalize=False, title="ANN Confusion Matrix (Test)", backgroundColor="white", marginTop=100, marginLeft=100, marginRight=100, marginBottom=100)
fig_cm.show()

# %% [markdown]
# ### Save the Model

# %%
ann.SaveModel(r"C:\Users\sarwj\OneDrive - Cardiff University\Desktop\ann_model.pt")

# %% [markdown]
# # ----- PHASE 2: PREDICTION OF UNSEEN DATASET ------

# %% [markdown]
# ### Load Testing Dataset

# %%
path=r"C:\Users\sarwj\OneDrive - Cardiff University\Documents\GitHub\topologicpy\assets\MachineLearning\synthetic_medium.csv"

# %% [markdown]
# ### Load the Pre-trained Model

# %%
# IMPORTANT: ANN.ByCSVPath expects a FILE path (not a folder)
ann_2 = ANN.ByCSVPath(
path=path,
task="classification",
featuresKeys=[f"x{i}" for i in range(50)],
labelHeader="label"
)


# IMPORTANT: epochs/batch_size are set via SetHyperparameters (Train() takes no args)
ann_2.SetHyperparameters(
epochs=125,
batch_size=3,          # <-- FIX (avoids batch size 1 with 5 training samples)
lr=1e-4,
weight_decay=1e-4,
hidden_dims=(64, 64),
dropout=0.1,
batch_norm=True,
early_stopping=True,
early_stopping_patience=20,
verbose=True
)
ann_2.LoadModel(r"C:\Users\sarwj\OneDrive - Cardiff University\Desktop\ann_model.pt")

# %% [markdown]
# ### Predict the Dataset

# %%
# Optional: predict on the same dataset (or pass path=... for new csv)
pred_pkg = ann_2.Predict(return_proba=True, attach_to_df=True)
df_pred = pred_pkg.get("df", None)
if isinstance(df_pred, pd.DataFrame):
    print("\nPredictions head:")
    print(df_pred.head())
# Out:
# Predictions head:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  0.091841 -2.377438  2.712184 -0.995119 -0.002728  1.288477  2.817108
# 1 -0.689990  1.874402  3.109361 -4.182978  2.523524 -0.223920  3.606342
# 2 -0.523490 -4.297341 -0.515422  1.019546  5.572912 -0.553417  3.173969
# 3 -1.802325 -1.260066  0.840554  6.505499  0.235186  0.636305 -1.430029
# 4 -0.597411 -0.307132  2.188670  0.057907 -0.304008 -1.482764 -6.192987
#
#           x7        x8        x9  ...       x48       x49  label  pred_label  \
# 0  -4.265892 -0.812775  0.569419  ...  2.535416  0.228359      2           2
# 1  -1.461277  1.897154  1.042749  ...  0.033004  1.085809      3           3
# 2 -11.362759 -1.483602  2.307871  ... -0.499515  0.587651      1           1
# 3   2.222442 -0.844897 -0.840617  ...  2.132421 -0.182430      0           0
# 4  -6.033078  6.868454 -5.909398  ... -3.012696  0.108499      1           1
#
#    pred   proba_0   proba_1   proba_2   proba_3   proba_4
# 0     2  0.007959  0.145162  0.419285  0.147820  0.279774
# 1     3  0.104382  0.244631  0.112758  0.476031  0.062199
# 2     1  0.004178  0.838860  0.044040  0.103353  0.009569
# 3     0  0.442726  0.126535  0.209144  0.112999  0.108596
# 4     1  0.000283  0.738419  0.003426  0.000933  0.256939
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Plot the Confusion Matrix (For Categorical Labels Only)

# %%
# Plot confusion matrix
fig_cm = ann.PlotConfusionMatrix(split="all", normalize=False, title="ANN Confusion Matrix (Test)", backgroundColor="white", marginTop=100, marginLeft=100, marginRight=100, marginBottom=100)
fig_cm.show()
